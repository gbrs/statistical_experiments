# %% [markdown]
# # А/Б тесты: непрерывные переменные | Вероятность и статистика #7
# Код из видео: https://www.youtube.com/watch?v=3lDeY5Uaxs4

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
pd.Series(np.random.normal(10,3,size=1000)).hist()
# Out:
# <AxesSubplot:>

# %%
pd.Series(np.random.normal(12,3,size=1000)).hist()
# Out:
# <AxesSubplot:>

# %%
from scipy.stats import ttest_ind

# %%
from tqdm.notebook import tqdm

# %%
## t-тест делаем на отличающихся выборках, созданных из нормального распределения
## запускали несколько раз три ячейки начиная с этой и подобрали sample_size = 36, чтобы мощность была ~0.80
baseline = 10
mde = 2
result = []
n = 10000
sample_size = 36
for _ in tqdm(range(n)):
  a = np.random.normal(baseline,3,size=sample_size)
  b = np.random.normal(baseline + mde,3,size=sample_size)
  _, pval = ttest_ind(a,b,equal_var=False)
  result.append(pval)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
t = pd.Series(result)  ## p-values

# %%
## мощность 
(t < 0.05).mean()
# Out:
# 0.7927

# %% [markdown]
# Проверим как распределено выборочное среднее

# %%
t = pd.Series([np.random.normal(10,3,size=36).mean() for _ in range(1000)])

# %%
t.hist()
# Out:
# <AxesSubplot:>

# %%
import pylab
import scipy.stats as stats

stats.probplot(t, dist="norm", plot=pylab)
pylab.show()

# %%
## qq-плот вполне приличный

# %%
##
import scipy.stats as sps
import statsmodels.api as sm
sm.qqplot(t, dist=sps.distributions.norm);

# %%
t = pd.Series(np.random.pareto(2,size=100))

# %%
t.hist()
# Out:
# <AxesSubplot:>

# %%
stats.probplot(t, dist="norm", plot=pylab)
pylab.show()

# %%
## распределение Паретто совсем не похоже на нормальное

# %%
## t-тест, когда у выборок, полученных из нормального распределения, нет отличий в среднем и дисперсии
baseline = 10
mde = 2
result = []
n = 10000
sample_size = 36
for _ in tqdm(range(n)):
  a = np.random.normal(baseline,3,size=sample_size)
  b = np.random.normal(baseline,3,size=sample_size)
  _, pval = ttest_ind(a,b,equal_var=False)
  result.append(pval)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
t = pd.Series(result)

# %%
t.hist()
# Out:
# <AxesSubplot:>

# %%
stats.probplot(t, dist="uniform", plot=pylab)
pylab.show()

# %%
## распределение p-значений вполне равномерное

# %%
## ошибка первого рода
(t < 0.05).mean()
# Out:
# 0.0498

# %% [markdown]
# Как проверить, что можно применять t test:
# - выборочное среднее распределено нормально (bootstrap + qq)
# - p-value для выборок из одного распределения имеет равномерное распределение (bootstrap + qq)
# - теоретический false positive == практическому false positive

# %%
## Рассичтаем размер выборки при наших параметрах:
## средние - 10 и 12, статзначимость - 0.05, хотим разницу 2 видеть в 80% случаев

# %%
import statsmodels.stats.api as sms

# %%
sample = pd.Series(np.random.normal(10,3,size=1000))

# %%
sample.std()
# Out:
# 3.029535060285824

# %%
es = (12 - 10)/ 2.9590190948628092

# %%
sms.TTestIndPower().solve_power(es, power=0.80, alpha=0.05, ratio=1)
# Out:
# 35.34802272010081

# %% [markdown]
# Ненормальное распределение
# ##выборочных данных

# %%
a = np.random.lognormal(mean=5, sigma=2, size=(100000,))
b = np.random.lognormal(mean=5.04, sigma=2, size=(100000,))

# %%
pd.Series(a).hist()
# Out:
# <AxesSubplot:>

# %%
t = pd.Series([np.random.lognormal(mean=5, sigma=2, size=(100000,)).mean() for _ in tqdm(range(1000))])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
t.hist()
# Out:
# <AxesSubplot:>

# %%
stats.probplot(t, dist="norm", plot=pylab)
pylab.show()

# %%
## видно, что исредние распределены ненормально. Тяжелый хвост справа

# %%
t.mean()
# Out:
# 1095.280830371346

# %%
result = []
n = 1000
for _ in tqdm(range(n)):
  a = np.random.lognormal(mean=5, sigma=2, size=(100000,))
  b = np.random.lognormal(mean=5, sigma=2, size=(100000,))
  _, pval = ttest_ind(a,b,equal_var=False)
  result.append(pval)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
t = pd.Series(result)

# %%
t.hist()
# Out:
# <AxesSubplot:>

# %%
stats.probplot(t, dist="uniform", plot=pylab)
pylab.show()

# %%
(t < 0.05).mean()
# Out:
# 0.057

# %%
## p-значения распределены равномерно

# %%
result = []
n = 1000
for _ in tqdm(range(n)):
  a = np.random.lognormal(mean=5, sigma=2, size=(100000,))
  b = np.random.lognormal(mean=5.04, sigma=2, size=(100000,))
  _, pval = ttest_ind(a,b,equal_var=False)
  result.append(pval)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
t = pd.Series(result)

# %%
(t < 0.05).mean()
# Out:
# 0.264

# %%
## но мощность даже при размере выборки в 100_000 ~0.25

# %%
## средние выборочные

# %%
a_mean_bs = pd.Series([np.random.lognormal(mean=5, sigma=2, size=(100000,)).mean() for _ in tqdm(range(1000))]).mean()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
b_mean_bs = pd.Series([np.random.lognormal(mean=5.04, sigma=2, size=(100000,)).mean() for _ in tqdm(range(1000))]).mean()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
a_mean_bs
# Out:
# 1095.5662564868849

# %%
b_mean_bs
# Out:
# 1141.434865408832

# %%
## теоретические средние по формуле исходя из параметров распределений

# %%
a_mean_math = np.exp(5 + (2**2)/2)

# %%
b_mean_math = np.exp(5.04 + (2**2)/2)

# %%
a_mean_math
# Out:
# 1096.6331584284585

# %%
b_mean_math
# Out:
# 1141.387606628968

# %%
a.std()
# Out:
# 5322.495099067132

# %%
## теперь можем посчитать необходимый размер выборки

# %%
es = (b_mean_math - a_mean_math)/ a.std()

# %%
es
# Out:
# 0.008408546624750006

# %%
sms.TTestIndPower().solve_power(es, power=0.80, alpha=0.05, ratio=1)
# Out:
# 222022.3106290011

# %%
t = pd.Series([np.random.lognormal(mean=5, sigma=2, size=(282693,)).mean() for _ in tqdm(range(1000))])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
t.hist()
# Out:
# <AxesSubplot:>

# %%
result = []
n = 1000
for _ in tqdm(range(n)):
  a = np.random.lognormal(mean=5, sigma=2, size=(282693,))
  b = np.random.lognormal(mean=5.04, sigma=2, size=(282693,))
  _, pval = ttest_ind(a,b,equal_var=False)
  result.append(pval)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
t = pd.Series(result)

# %%
(t < 0.05).mean()
# Out:
# 0.563

# %%
## Глеб попробовал симулировать при таком размере выборки, но почему-то мощность к 0.80 не пришла
## Видимо, нельзя считать размер выборки этой функцией - она же для t-теста

# %%
## поподгонял мощность до 0.80. При ~500_000-ной выборке

# %%
result = []
n = 1000
size = 530_000
for _ in tqdm(range(n)):
  a = np.random.lognormal(mean=5, sigma=2, size=(size, ))
  b = np.random.lognormal(mean=5.04, sigma=2, size=(size, ))
  _, pval = ttest_ind(a,b,equal_var=False)
  result.append(pval)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
t = pd.Series(result)

# %%
(t < 0.05).mean()
# Out:
# 0.827

# %%
result = []
n = 1000
for _ in tqdm(range(n)):
  a = np.log(np.random.lognormal(mean=5, sigma=2, size=(100000,)))
  b = np.log(np.random.lognormal(mean=5.04, sigma=2, size=(100000,)))
  _, pval = ttest_ind(a,b,equal_var=False)
  result.append(pval)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
t = pd.Series(result)

# %%
(t < 0.05).mean()
# Out:
# 0.995

# %%
## если данные пролагорифмировать, то мощность даже при 100_000 - 0.995

# %%
a = np.random.lognormal(mean=5, sigma=2, size=(100000,))

# %%
a.mean()
# Out:
# 1151.964670585425

# %%
np.log(a).std()
# Out:
# 2.003476716643833

# %%
es = (np.log(b_mean_math) - np.log(a_mean_math))/ np.log(a).std()

# %%
es
# Out:
# 0.019965293166474572

# %%
## считаем размер выборки для прологарифмирванной выборки.

# %%
sms.TTestIndPower().solve_power(es, power=0.80, alpha=0.05, ratio=1)
# Out:
# 39381.82342452465

# %%
result = []
n = 1000
for _ in tqdm(range(n)):
  a = np.log(np.random.lognormal(mean=5, sigma=2, size=(39246,)))
  b = np.log(np.random.lognormal(mean=5.04, sigma=2, size=(39246,)))
  _, pval = ttest_ind(a,b,equal_var=False)
  result.append(pval)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
t = pd.Series(result)

# %%
(t < 0.05).mean()
# Out:
# 0.812

# %%
## мощность ~0.80

# %%
! gdown --id 1zLKWeJ_OZjxuKlP561-GopniC0_Pt_X6
# Out:
# 'gdown' is not recognized as an internal or external command,
# operable program or batch file.

# %%
df = pd.read_csv('/content/age_children_income_1000.csv')

# %%
df
# Out:
#            age  number_of_children         income
# 0    42.772420                   0   34396.537188
# 1    29.561090                   0  183350.052521
# 2    54.380735                   0   53689.856555
# 3    42.551689                   0  109080.913926
# 4    38.713080                   0  153612.343419
# ..         ...                 ...            ...
# 995  36.281055                   0  128647.922872
# 996  18.472716                   0   67204.531673
# 997  40.547748                   0  139432.757984
# 998  24.791760                   1  137526.452334
# 999  46.662848                   0  148449.261137
#
# [1000 rows x 3 columns]

# %%
df['income'].mean()
# Out:
# 129415.7463784342

# %%
df['income'].hist()

# %%
pd.Series([df['income'].sample(1000,replace=True).mean() for _ in range(1000)]).hist()

# %%
es = (150000 - 130000) / df['income'].std()

# %%
es
# Out:
# 0.2806953684356606

# %%
sms.TTestIndPower().solve_power(es, power=0.80, alpha=0.05, ratio=1)
# Out:
# 200.20012721743495

# %%
np.log(df['income']).hist()

# %%
import warnings
import numpy as np
import pandas as pd
import scipy.stats as st
import statsmodels.api as sm
from scipy.stats._continuous_distns import _distn_names
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')

# Create models from data
def best_fit_distribution(data, bins=200, ax=None):
    """Model data by finding best fit distribution to data"""
    # Get histogram of original data
    y, x = np.histogram(data, bins=bins, density=True)
    x = (x + np.roll(x, -1))[:-1] / 2.0

    # Best holders
    best_distributions = []

    # Estimate distribution parameters from data
    for ii, distribution in enumerate([d for d in _distn_names if not d in ['levy_stable', 'studentized_range']]):

        print("{:>3} / {:<3}: {}".format( ii+1, len(_distn_names), distribution ))

        distribution = getattr(st, distribution)

        # Try to fit the distribution
        try:
            # Ignore warnings from data that can't be fit
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')

                # fit dist to data
                params = distribution.fit(data)

                # Separate parts of parameters
                arg = params[:-2]
                loc = params[-2]
                scale = params[-1]

                # Calculate fitted PDF and error with fit in distribution
                pdf = distribution.pdf(x, loc=loc, scale=scale, *arg)
                sse = np.sum(np.power(y - pdf, 2.0))

                # if axis pass in add to plot
                try:
                    if ax:
                        pd.Series(pdf, x).plot(ax=ax)
                    end
                except Exception:
                    pass

                # identify if this distribution is better
                best_distributions.append((distribution, params, sse))

        except Exception:
            pass


    return sorted(best_distributions, key=lambda x:x[2])

def make_pdf(dist, params, size=10000):
    """Generate distributions's Probability Distribution Function """

    # Separate parts of parameters
    arg = params[:-2]
    loc = params[-2]
    scale = params[-1]

    # Get sane start and end points of distribution
    start = dist.ppf(0.01, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.01, loc=loc, scale=scale)
    end = dist.ppf(0.99, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.99, loc=loc, scale=scale)

    # Build PDF and turn into pandas Series
    x = np.linspace(start, end, size)
    y = dist.pdf(x, loc=loc, scale=scale, *arg)
    pdf = pd.Series(y, x)

    return pdf

# Load data from statsmodels datasets
data = df['income']

# Plot for comparison
plt.figure(figsize=(12,8))
ax = data.plot(kind='hist', bins=50, density=True, alpha=0.5, color=list(matplotlib.rcParams['axes.prop_cycle'])[1]['color'])

# Save plot limits
dataYLim = ax.get_ylim()

# Find best fit distribution
best_distibutions = best_fit_distribution(data, 200, ax)
best_dist = best_distibutions[0]

# Update plots
ax.set_ylim(dataYLim)
ax.set_title(u'El Niño sea temp.\n All Fitted Distributions')
ax.set_xlabel(u'Temp (°C)')
ax.set_ylabel('Frequency')

# Make PDF with best params
pdf = make_pdf(best_dist[0], best_dist[1])

# Display
plt.figure(figsize=(12,8))
ax = pdf.plot(lw=2, label='PDF', legend=True)
data.plot(kind='hist', bins=50, density=True, alpha=0.5, label='Data', legend=True, ax=ax)

param_names = (best_dist[0].shapes + ', loc, scale').split(', ') if best_dist[0].shapes else ['loc', 'scale']
param_str = ', '.join(['{}={:0.2f}'.format(k,v) for k,v in zip(param_names, best_dist[1])])
dist_str = '{}({})'.format(best_dist[0].name, param_str)

ax.set_title(u'El Niño sea temp. with best fit distribution \n' + dist_str)
ax.set_xlabel(u'Temp. (°C)')
ax.set_ylabel('Frequency')
# Out:
#   1 / 100: ksone
#   2 / 100: kstwobign
#   3 / 100: norm
#   4 / 100: alpha
#   5 / 100: anglit
#   6 / 100: arcsine
#   7 / 100: beta
#   8 / 100: betaprime
#   9 / 100: bradford
#  10 / 100: burr
#  11 / 100: burr12
#  12 / 100: fisk
#  13 / 100: cauchy
#  14 / 100: chi
#  15 / 100: chi2
#  16 / 100: cosine
#  17 / 100: dgamma
#  18 / 100: dweibull
#  19 / 100: expon
#  20 / 100: exponnorm
#  21 / 100: exponweib
#  22 / 100: exponpow
#  23 / 100: fatiguelife
#  24 / 100: foldcauchy
#  25 / 100: f
#  26 / 100: foldnorm
#  27 / 100: weibull_min
#  28 / 100: weibull_max
#  29 / 100: frechet_r
#  30 / 100: frechet_l
#  31 / 100: genlogistic
#  32 / 100: genpareto
#  33 / 100: genexpon
#  34 / 100: genextreme
#  35 / 100: gamma
#  36 / 100: erlang
#  37 / 100: gengamma
#  38 / 100: genhalflogistic
#  39 / 100: gompertz
#  40 / 100: gumbel_r
#  41 / 100: gumbel_l
#  42 / 100: halfcauchy
#  43 / 100: halflogistic
#  44 / 100: halfnorm
#  45 / 100: hypsecant
#  46 / 100: gausshyper
#  47 / 100: invgamma
#  48 / 100: invgauss
#  49 / 100: geninvgauss
#  50 / 100: norminvgauss
#  51 / 100: invweibull
#  52 / 100: johnsonsb
#  53 / 100: johnsonsu
#  54 / 100: laplace
#  55 / 100: levy
#  56 / 100: levy_l
#  57 / 100: logistic
#  58 / 100: loggamma
#  59 / 100: loglaplace
#  60 / 100: lognorm
#  61 / 100: gilbrat
#  62 / 100: maxwell
#  63 / 100: mielke
#  64 / 100: kappa4
#  65 / 100: kappa3
#  66 / 100: moyal
#  67 / 100: nakagami
#  68 / 100: ncx2
#  69 / 100: ncf
#  70 / 100: t
#  71 / 100: nct
#  72 / 100: pareto
#  73 / 100: lomax
#  74 / 100: pearson3
#  75 / 100: powerlaw
#  76 / 100: powerlognorm
#  77 / 100: powernorm
#  78 / 100: rdist
#  79 / 100: rayleigh
#  80 / 100: loguniform
#  81 / 100: reciprocal
#  82 / 100: rice
#  83 / 100: recipinvgauss
#  84 / 100: semicircular
#  85 / 100: skewnorm
#  86 / 100: trapz
#  87 / 100: triang
#  88 / 100: truncexpon
#  89 / 100: truncnorm
#  90 / 100: tukeylambda
#  91 / 100: uniform
#  92 / 100: vonmises
#  93 / 100: vonmises_line
#  94 / 100: wald
#  95 / 100: wrapcauchy
#  96 / 100: gennorm
#  97 / 100: halfgennorm
#  98 / 100: crystalball
#  99 / 100: argus
# Text(0, 0.5, 'Frequency')

# %%
t = pd.DataFrame(best_distibutions).sort_values(2)

# %%
t[0][0]

# %%
t[1][0]
# Out:
# (8.635547387774977, 1.940117105713055, -622.73639508824, 9922160.800678246)

# %%
from scipy.stats import johnsonsb

# %%
t
# Out:
#                                                     0  ...             2
# 0   <scipy.stats._continuous_distns.johnsonsb_gen ...  ...  1.079567e-10
# 1   <scipy.stats._continuous_distns.johnsonsu_gen ...  ...  1.080420e-10
# 2   <scipy.stats._continuous_distns.moyal_gen obje...  ...  1.087651e-10
# 3   <scipy.stats._continuous_distns.invgamma_gen o...  ...  1.094373e-10
# 4   <scipy.stats._continuous_distns.pearson3_gen o...  ...  1.110460e-10
# ..                                                ...  ...           ...
# 96  <scipy.stats._continuous_distns.recipinvgauss_...  ...  1.963693e-08
# 97  <scipy.stats._continuous_distns.vonmises_gen o...  ...  5.570466e+47
# 91  <scipy.stats._continuous_distns.mielke_gen obj...  ...           NaN
# 95  <scipy.stats._continuous_distns.powernorm_gen ...  ...           NaN
# 98  <scipy.stats._continuous_distns.wrapcauchy_gen...  ...           NaN
#
# [99 rows x 3 columns]

# %%
a, b = -622.73639508824, 9922160.800678246
mean, var, skew, kurt = johnsonsb.stats(a, b, moments='mvsk')

# %%
mean
# Out:
# array(0.50001569)

# %%
(df['income'] + 20000).mean()
# Out:
# 149415.746378434

# %%
(df['income'] + 20000).hist()

# %%
df['income']
# Out:
# 0       34396.537188
# 1      183350.052521
# 2       53689.856555
# 3      109080.913926
# 4      153612.343419
#            ...
# 995    128647.922872
# 996     67204.531673
# 997    139432.757984
# 998    137526.452334
# 999    148449.261137
# Name: income, Length: 1000, dtype: float64

# %%
from scipy.stats import mannwhitneyu

# %%
result = []
n = 100
for _ in tqdm(range(n)):
  a = np.log(np.random.lognormal(mean=5, sigma=2, size=(42000,)))
  b = np.log(np.random.lognormal(mean=5.04, sigma=2, size=(42000,)))
  _, pval = mannwhitneyu(a,b,alternative='two-sided')
  result.append(pval)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
t = pd.Series(result)

# %%
(t < 0.05).mean()
# Out:
# 0.84

# %%
result = []
n = 100
for _ in tqdm(range(n)):
  a = np.log(np.random.lognormal(mean=5, sigma=2, size=(30000,)))
  b = np.log(np.random.lognormal(mean=5, sigma=2, size=(30000,)))
  _, pval = mannwhitneyu(a,b)
  result.append(pval)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
t = pd.Series(result)

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
stats.probplot(t, dist="uniform", plot=pylab)
pylab.show()

# %%
(t < 0.05).mean()
# Out:
# 0.14

# %%
result = []
n = 1000
for _ in tqdm(range(n)):
  a = np.log(np.random.lognormal(mean=5, sigma=2, size=(100000,)))
  b = np.log(np.random.lognormal(mean=5, sigma=2, size=(100000,)))
  _, pval = mannwhitneyu(a,b,alternative='two-sided')
  result.append(pval)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
t = pd.Series(result)

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
stats.probplot(t, dist="uniform", plot=pylab)
pylab.show()

# %%
(t < 0.05).mean()
# Out:
# 0.054

# %%
t.hist()

# %%
mannwhitneyu()
